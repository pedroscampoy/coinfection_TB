# %%
import pandas as pd
import os
import sys
from itertools import permutations

# %%
def import_to_pandas(file_table, sep='\t'):
    #Use first line as header
    dataframe = pd.read_csv(file_table, sep=sep, header=0)
    return dataframe

# %%
df_P15050 = import_to_pandas('test/PAIR1_50_50_coinfection-designed.gatk_position_table.tab')

# %%
df_P15050.head()
# Out:
#    #Pos  Insindex RefBase  As  Cs  Gs  Ts  Ns  GAPs  as  ...  gs  ts  ns  \
# 0     1         0       T   0   0   0  49   0     0   0  ...   0  10   0
# 1     2         0       T   0   0   0  49   0     0   0  ...   0  10   0
# 2     3         0       G   0   0  51   0   0     0   0  ...  13   0   0
# 3     4         0       A  51   0   0   0   0     0  13  ...   0   0   0
# 4     5         0       C   0  51   0   0   0     0   0  ...   0   0   0
#
#    gaps  Aqual_20  Cqual_20  G_qual_20  Tqual_20  Nqual_20  GAPqual_20
# 0     0         0         0          0        59         0           0
# 1     0         0         0          0        59         0           0
# 2     0         0         0         64         0         0           0
# 3     0        64         0          0         0         0           0
# 4     0         0        64          0         0         0           0
#
# [5 rows x 21 columns]

# %%
df_P15050.shape
# Out:
# (4412350, 21)

# %%
perm = permutations(['As', 'Cs', 'Gs', 'Ts'], 2)
#filterinfDataframe = dfObj[(dfObj['Sale'] > 30) & (dfObj['Sale'] < 33) ]
df = 'df_P15050'
logical_list = []
for i in perm:
    and_boolean = "(%s['%s']>4) & (%s['%s']>4)" % (df,i[0],df,i[1])
    logical_list.append(and_boolean)

full_perm_filter ="(" + ") | (".join(logical_list) + ")"

#str(full_perm_filter)
#full_perm_filter = print(full_perm_filter)

full_perm_filter
#logical_list
#print(len(logical_list))
# Out:
# "((df_P15050['As']>4) & (df_P15050['Cs']>4)) | ((df_P15050['As']>4) & (df_P15050['Gs']>4)) | ((df_P15050['As']>4) & (df_P15050['Ts']>4)) | ((df_P15050['Cs']>4) & (df_P15050['As']>4)) | ((df_P15050['Cs']>4) & (df_P15050['Gs']>4)) | ((df_P15050['Cs']>4) & (df_P15050['Ts']>4)) | ((df_P15050['Gs']>4) & (df_P15050['As']>4)) | ((df_P15050['Gs']>4) & (df_P15050['Cs']>4)) | ((df_P15050['Gs']>4) & (df_P15050['Ts']>4)) | ((df_P15050['Ts']>4) & (df_P15050['As']>4)) | ((df_P15050['Ts']>4) & (df_P15050['Cs']>4)) | ((df_P15050['Ts']>4) & (df_P15050['Gs']>4))"

# %%
#mask = df_P15050[((df_P15050['As']>4) & (df_P15050['Cs']>4)) | ((df_P15050['As']>4) & (df_P15050['Gs']>4)) | ((df_P15050['As']>4) & (df_P15050['Ts']>4)) | ((df_P15050['Cs']>4) & (df_P15050['As']>4)) | ((df_P15050['Cs']>4) & (df_P15050['Gs']>4)) | ((df_P15050['Cs']>4) & (df_P15050['Ts']>4)) | ((df_P15050['Gs']>4) & (df_P15050['As']>4)) | ((df_P15050['Gs']>4) & (df_P15050['Cs']>4)) | ((df_P15050['Gs']>4) & (df_P15050['Ts']>4)) | ((df_P15050['Ts']>4) & (df_P15050['As']>4)) | ((df_P15050['Ts']>4) & (df_P15050['Cs']>4)) | ((df_P15050['Ts']>4) & (df_P15050['Gs']>4))]
#df_P15050['full_perm_filter']
mask = df_P15050[((df_P15050['As']>4) & (df_P15050['Cs']>4)) | ((df_P15050['As']>4) & (df_P15050['Gs']>4)) | ((df_P15050['As']>4) & (df_P15050['Ts']>4)) | ((df_P15050['Cs']>4) & (df_P15050['As']>4)) | ((df_P15050['Cs']>4) & (df_P15050['Gs']>4)) | ((df_P15050['Cs']>4) & (df_P15050['Ts']>4)) | ((df_P15050['Gs']>4) & (df_P15050['As']>4)) | ((df_P15050['Gs']>4) & (df_P15050['Cs']>4)) | ((df_P15050['Gs']>4) & (df_P15050['Ts']>4)) | ((df_P15050['Ts']>4) & (df_P15050['As']>4)) | ((df_P15050['Ts']>4) & (df_P15050['Cs']>4)) | ((df_P15050['Ts']>4) & (df_P15050['Gs']>4))]

# %%
mask.head(50)
# Out:
#           #Pos  Insindex RefBase  As   Cs   Gs   Ts  Ns  GAPs  as  ...   gs  \
# 6141      6140         0       G   0    0   57   28   0     0   0  ...   52
# 6770      6769         0       C   0   93    0    5   0     0   0  ...    0
# 6776      6775         0       G   1    0   90    5   0     0   1  ...   86
# 6785      6784         0       C   6   91    0    0   0     0   7  ...    0
# 6794      6793         0       T   0    6    0   89   0     0   0  ...    0
# 6797      6796         0       C   0   86    0    7   0     0   0  ...    0
# 6799      6798         0       G   7    0   85    0   0     0   7  ...   86
# 6800      6799         0       C   0   86    6    0   0     0   0  ...    6
# 6813      6812         0       C   8   82    0    0   0     0   8  ...    0
# 6836      6835         0       C   0   82    0    9   0     0   1  ...    0
# 6842      6841         0       T   0    9    0   80   0     0   0  ...    1
# 7586      7585         0       C   0   10   22    0   0     0   0  ...   21
# 9305      9304         0       A  22    0   37    0   0     0  21  ...   36
# 10742    10741         0       C   0   16   25    0   0     0   0  ...   30
# 13637    13636         0       T   0   32    0   36   0     0   0  ...    0
# 14252    14251         0       G  11    0    6    0   0     0  16  ...   18
# 15123    15122         0       A   9    0   20    0   0     0  11  ...    8
# 17609    17608         0       G   0   15   21    0   0     0   0  ...   27
# 24817    24816         0       G   0   18   32    0   0     0   0  ...   37
# 24895    24894         0       T   0   17    0   23   0     0   0  ...    0
# 33459    33457         0       C   0   14    0   16   0     0   0  ...    0
# 33553    33551         0       T   0    0    8   14   0     0   0  ...   14
# 35099    35097         0       T   0   32    0   43   0     0   0  ...    0
# 40165    40162         0       C   0   28    0   10   0     0   0  ...    0
# 46337    46334         0       G  35    0   18    0   0     0  26  ...   19
# 49442    49439         0       C   0    9    0    6   0     0   0  ...    0
# 60142    60131         0       C   0   61    0   71   0     0   0  ...    0
# 61340    61329         0       C   0   24    0   32   0     0   0  ...    0
# 63783    63771         0       C   0   47    0   34   0     0   0  ...    0
# 63909    63897         0       G   0    0   19   28   0     0   0  ...   38
# 74108    74059         0       C   0   21    0   13   0     0   0  ...    0
# 80683     0   0     0         0        40         69         0         0
# 81565    71   0     0         0         0          0        97         0
# 81990     0   0     0        43         0         63         0         0
# 90653     0   0     0        40         0         33         0         0
# 92269    12   0     0         0         0         23        18         0
# 96119    11   0     0         0        26          0        22         0
# 100837    0   0     0        23         0         15         0         0
# 101797    0   0     0        22         0         33         0         0
# 103826    6   0     0         0         0        559        19         0
# 103906  151   0     0         0         0        281       254         0
# 103949  110   0     0         0       229          0       152         0
# 103963    0   0     0         0       336         35         0         0
# 103966    0   0     0         0       339         37         0         0
# 104782   30   0     0         1        97          0        56         0
#
#         GAPqual_20
# 6141             0
# 6770             0
# 6776             0
# 6785             0
# 6794             0
# 6797             0
# 6799             0
# 6800             0
# 6813             0
# 6836             0
# 6842             0
# 7586             0
# 9305             0
# 10742            0
# 13637            0
# 14252            0
# 15123            0
# 17609            0
# 24817            0
# 24895            0
# 33459            0
# 33553            0
# 35099            0
# 40165            0
# 46337            0
# 49442            0
# 60142            0
# 61340            0
# 63783            0
# 63909            0
# 74108            0
# 79478            0
# 79850            0
# 80418            0
# 80540            0
# 80542            0
# 80683            0
# 81565            0
# 81990            0
# 90653            0
# 92269            0
# 96119            0
# 100837           0
# 101797           0
# 103826           0
# 103906           0
# 103949           0
# 103963           0
# 103966           0
# 104782           0
#
# [50 rows x 21 columns]

# %%
mask.shape
# Out:
# (2141, 21)

# %%
example = df_P15050[(((df_P15050['As']>4) & (df_P15050['Cs']>4)) | ((df_P15050['As']>4) & (df_P15050['Gs']>4)))]

# %%
example.head(5)
# Out:
#         #Pos  Insindex RefBase  As  Cs  Gs  Ts  Ns  GAPs  as  ...  gs  ts  ns  \
# 6785    6784         0       C   6  91   0   0   0     0   7  ...   0   0   0
# 6799    6798         0       G   7   0  85   0   0     0   7  ...  86   0   0
# 6813    6812         0       C   8  82   0   0   0     0   8  ...   0   0   0
# 9305    9304         0       A  22   0  37   0   0     0  21  ...  36   0   0
# 14252  14251         0       G  11   0   6   0   0     0  16  ...  18   0   0
#
#        gaps  Aqual_20  Cqual_20  G_qual_20  Tqual_20  Nqual_20  GAPqual_20
# 6785      0        13       175          0         0         0           0
# 6799      0        14         0        170         0         0           0
# 6813      0        16       167          0         0         0           0
# 9305      0        43         0         72         0         0           0
# 14252     0        26         0         24         0         0           0
#
# [5 rows x 21 columns]

# %%
filter = "(((df_P15050['As']>4) & (df_P15050['Cs']>4)) | ((df_P15050['As']>4) & (df_P15050['Gs']>4)))"
filter
# Out:
# "(((df_P15050['As']>4) & (df_P15050['Cs']>4)) | ((df_P15050['As']>4) & (df_P15050['Gs']>4)))"

# %%
example2 = df_P15050['filter']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/env36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'filter'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-a060853ae576> in <module>
# ----> 1 example2 = df_P15050['filter']
#
# ~/env36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/env36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'filter'
